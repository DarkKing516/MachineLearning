# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.scatter([1,2,3,4], [1,2,0,0.5])
plt.show()

# %%
data=pd.read_excel('Clientes.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     38 non-null     int64
#  1   Factura        38 non-null     object
#  2   Cliente        38 non-null     object
#  3   Ubicación      38 non-null     object
#  4   Genero         38 non-null     object
#  5   Producto       38 non-null     object
#  6   TipoVenta      38 non-null     object
#  7   Cantidad       38 non-null     int64
#  8   ValorUnitario  38 non-null     int64
#  9   SUBTOTAL       38 non-null     int64
# dtypes: int64(4), object(6)
# memory usage: 3.1+ KB

# %%
data.groupby(data['Genero']).count()
# Out:
#         Unnamed: 0  Factura  Cliente  Ubicación  Producto  TipoVenta  \
# Genero
# Hombre          18       18       18         18        18         18
# Mujer           20       20       20         20        20         20
#
#         Cantidad  ValorUnitario  SUBTOTAL
# Genero
# Hombre        18             18        18
# Mujer         20             20        20

# %%
fig, ax = plt.subplots()
ax.scatter(data['Cantidad'], data['ValorUnitario'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(data['Cantidad'], data['ValorUnitario'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.fill_between(data['Cantidad'], data['ValorUnitario'])
plt.show()

# %%
mipdata[data['Cantidad'] == 2]

# %%
datosx = data['Genero'].unique()
