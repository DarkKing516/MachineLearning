# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
datasetc = pd.read_excel('Datosestadisticos.xlsx', sheet_name = 'Cuantitativos_Discretos')

# %%
datasetc.describe()
# Out:
#        Talla_Zapatos
# count      50.000000
# mean       38.040000
# std         3.155559
# min        31.000000
# 25%        36.000000
# 50%        38.000000
# 75%        40.000000
# max        44.000000

# %%
print(datasetc.mean())
print(datasetc.min())
print(datasetc.max())
print(datasetc.median())
# Out:
# Talla_Zapatos    38.04
# dtype: float64
# Talla_Zapatos    31
# dtype: int64
# Talla_Zapatos    44
# dtype: int64
# Talla_Zapatos    38.0
# dtype: float64

# %%
datasetc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Talla_Zapatos  50 non-null     int64
# dtypes: int64(1)
# memory usage: 532.0 bytes

# %%
frecuencia =datasetc['Talla_Zapatos'].value_counts().reset_index()

# %%
frecuencia
# Out:
#     Talla_Zapatos  count
# 0              38      8
# 1              39      8
# 2              37      5
# 3              40      5
# 4              33      4
# 5              36      4
# 6              42      4
# 7              34      2
# 8              35      2
# 9              41      2
# 10             43      2
# 11             44      2
# 12             31      1
# 13             32      1

# %%
frecuencia.head()
# Out:
#    Talla_Zapatos  count
# 0             38      8
# 1             39      8
# 2             37      5
# 3             40      5
# 4             33      4

# %%
frecuencia.columns=['Talla Zapatos', 'Frecuencia A']

frecuencia['Frecuencia A AD'] = frecuencia['Frecuencia A'].cumsum()

frecuencia
# Out:
#     Talla Zapatos  Frecuencia A  Frecuencia A AD
# 0              38             8                8
# 1              39             8               16
# 2              37             5               21
# 3              40             5               26
# 4              33             4               30
# 5              36             4               34
# 6              42             4               38
# 7              34             2               40
# 8              35             2               42
# 9              41             2               44
# 10             43             2               46
# 11             44             2               48
# 12             31             1               49
# 13             32             1               50

# %%
suma_adsoulta = frecuencia['Frecuencia A'].sum()

frecuencia['Frecuencia R'] = frecuencia['Frecuencia A'] / suma_adsoulta

frecuencia
# Out:
#     Talla Zapatos  Frecuencia A  Frecuencia A AD  Frecuencia R
# 0              38             8                8          0.16
# 1              39             8               16          0.16
# 2              37             5               21          0.10
# 3              40             5               26          0.10
# 4              33             4               30          0.08
# 5              36             4               34          0.08
# 6              42             4               38          0.08
# 7              34             2               40          0.04
# 8              35             2               42          0.04
# 9              41             2               44          0.04
# 10             43             2               46          0.04
# 11             44             2               48          0.04
# 12             31             1               49          0.02
# 13             32             1               50          0.02

# %%
frecuencia['Frecuencia R A'] = frecuencia['Frecuencia R'].cumsum()

frecuencia
# Out:
#     Talla Zapatos  Frecuencia A  Frecuencia A AD  Frecuencia R  Frecuencia R A
# 0              38             8                8          0.16            0.16
# 1              39             8               16          0.16            0.32
# 2              37             5               21          0.10            0.42
# 3              40             5               26          0.10            0.52
# 4              33             4               30          0.08            0.60
# 5              36             4               34          0.08            0.68
# 6              42             4               38          0.08            0.76
# 7              34             2               40          0.04            0.80
# 8              35             2               42          0.04            0.84
# 9              41             2               44          0.04            0.88
# 10             43             2               46          0.04            0.92
# ...

# %%
plt.figure(figsize=(10, 5))
plt.bar(frecuencia['Talla Zapatos'], frecuencia['Frecuencia A'], color='blue', alpha=0.7)
plt.xlabel('Talla de Zapatos')
# plt.ylabel('Frecuencia Absoluta')
plt.title('Frecuencia Absoluta')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(frecuencia['Talla Zapatos'], frecuencia['Frecuencia A AD'], marker='o', linestyle='-', color='red')
plt.xlabel('Talla de Zapatos')
plt.ylabel('Frecuencia Acumulada')
plt.title('Frecuencia Acumulada')
plt.grid(axis='y')
plt.show()

# %%
plt.hist(frecuencia['Frecuencia A AD'], bins=4, edgecolor='black', color="green")

plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('Histograma de Frecuencia Acumulada')

plt.show()

# %%
datasetUwU = pd.read_excel('Datosestadisticos.xlsx', sheet_name='Cuantitativos_Continuos')

datasetUwU
# Out:
#     Peso_Estudiantes
# 0               66.4
# 1               65.7
# 2               56.9
# 3               70.8
# 4               77.5
# 5               80.5
# 6               90.6
# 7               89.5
# 8               77.8
# 9               79.6
# 10              80.3
# 11              80.3
# 12              67.9
# 13              72.3
# 14              74.5
# 15              80.5
# 16              89.6
# 17              78.9
# 18              89.2
# 19              74.6
# 20              82.4
# 21              83.9
# 22              80.3
# 23              66.9
# 24              74.6
# 25              69.6
# 26              88.9
# 27              84.3
# 28              66.1
# 29              84.9
# 30              74.9
# 31              72.6
# 32              67.8
# 33              72.1
# 34              75.2
# 35              70.3
# 36              76.5
# 37              88.9
# 38              75.4
# 39              79.6
# 40              83.2
# 41              77.1
# ...

# %%
num_intervalos = int(1 + 3.322 * np.log10(len(datasetUwU)))

num_intervalo2 = int(1 + np.log2(len(datasetUwU)))

print(num_intervalos, num_intervalo2)
# Out:
# 6 6

# %%
datasetUwU['Intervalos'] = pd.cut(datasetUwU['Peso_Estudiantes'], bins = num_intervalos)
datasetUwU['Intervalos'] = pd.cut(datasetUwU['Peso_Estudiantes'], bins=num_intervalos)
datasetUwU
# Out:
#     Peso_Estudiantes        Intervalos
# 0               66.4  (62.517, 68.133]
# 1               65.7  (62.517, 68.133]
# 2               56.9  (56.866, 62.517]
# 3               70.8   (68.133, 73.75]
# 4               77.5   (73.75, 79.367]
# 5               80.5  (79.367, 84.983]
# 6               90.6    (84.983, 90.6]
# 7               89.5    (84.983, 90.6]
# 8               77.8   (73.75, 79.367]
# 9               79.6  (79.367, 84.983]
# 10              80.3  (79.367, 84.983]
# 11              80.3  (79.367, 84.983]
# 12              67.9  (62.517, 68.133]
# 13              72.3   (68.133, 73.75]
# 14              74.5   (73.75, 79.367]
# 15              80.5  (79.367, 84.983]
# 16              89.6    (84.983, 90.6]
# 17              78.9   (73.75, 79.367]
# 18              89.2    (84.983, 90.6]
# 19              74.6   (73.75, 79.367]
# 20              82.4  (79.367, 84.983]
# 21              83.9  (79.367, 84.983]
# 22              80.3  (79.367, 84.983]
# ...

# %%
Frecuenciaxd = datasetUwU['Intervalos'].value_counts().sort_index().reset_index()
Frecuenciaxd
# Out:
#          Intervalos  count
# 0  (56.866, 62.517]      1
# 1  (62.517, 68.133]      6
# 2   (68.133, 73.75]      7
# 3   (73.75, 79.367]     15
# 4  (79.367, 84.983]     12
# 5    (84.983, 90.6]      9

# %%
Frecuenciaxd.columns = ['Intervalos', 'Frecuencia A']

Frecuenciaxd['Frecuencia A A'] = Frecuenciaxd['Frecuencia A'].cumsum()
Frecuenciaxd
# Out:
#          Intervalos  Frecuencia A  Frecuencia A A
# 0  (56.866, 62.517]             1               1
# 1  (62.517, 68.133]             6               7
# 2   (68.133, 73.75]             7              14
# 3   (73.75, 79.367]            15              29
# 4  (79.367, 84.983]            12              41
# 5    (84.983, 90.6]             9              50

# %%
plt.figure(figsize=(10, 5))
plt.bar(Frecuenciaxd['Intervalos'].astype(str), Frecuenciaxd['Frecuencia A'], color='skyblue')
plt.xlabel('Intervalos')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de cada intervalo')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(Frecuenciaxd['Intervalos'].astype(str), Frecuenciaxd['Frecuencia A A'], marker='o', color='b')
plt.xlabel('Intervalos')
plt.ylabel('Frecuencia Acumulada')
plt.title('Frecuencia Acumulada')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # **Cualitativos**

# %%
datoscontinuos = pd.read_excel('Datosestadisticos.xlsx', sheet_name='Cualitativos')
datoscontinuos
# Out:
#    Nivel_Escolar
# 0       Primaria
# 1      Bachiller
# 2    Profesional
# 3      Postgrado
# 4        Ninguno
# 5        Ninguno
# 6        Ninguno
# 7       Primaria
# 8    Profesional
# 9    Profesional
# 10   Profesional
# 11   Profesional
# 12     Postgrado
# 13     Postgrado
# 14     Bachiller
# 15       Tecnico
# 16       Tecnico
# 17       Tecnico
# 18   Tecnologico
# 19   Tecnologico
# 20   Tecnologico
# 21   Tecnologico
# 22   Tecnologico
# 23   Profesional
# 24     Bachiller
# 25     Postgrado
# 26   Profesional
# 27       Tecnico
# 28   Tecnologico
# 29       Ninguno
# 30       Tecnico
# 31       Tecnico
# 32   Tecnologico
# 33   Tecnologico
# 34   Profesional
# 35   Profesional
# 36     Bachiller
# 37     Bachiller
# 38     Bachiller
# 39       Ninguno
# 40   Profesional
# 41     Postgrado
# 42     Bachiller
# 43     Bachiller
# 44       Tecnico
# 45       Tecnico
# 46   Tecnologico
# 47   Tecnologico
# 48   Tecnologico
# 49   Profesional

# %%
frecienciaC = datoscontinuos['Nivel_Escolar'].value_counts().reset_index()

frecienciaC
# Out:
#   Nivel_Escolar  count
# 0   Profesional     11
# 1   Tecnologico     11
# 2     Bachiller      8
# 3       Tecnico      8
# 4     Postgrado      5
# 5       Ninguno      5
# 6      Primaria      2

# %%
frecienciaC.columns = ['Nivel Escolar', 'Freciencia AD']

frecienciaC
# Out:
#   Nivel Escolar  Freciencia AD
# 0   Profesional             11
# 1   Tecnologico             11
# 2     Bachiller              8
# 3       Tecnico              8
# 4     Postgrado              5
# 5       Ninguno              5
# 6      Primaria              2

# %%
frecienciaC['Freciencia A AD'] = frecienciaC['Freciencia AD'].cumsum()

suma_acumulada = frecienciaC['Freciencia AD'].sum()

frecienciaC['Freciencia R'] = frecienciaC['Freciencia AD']/suma_acumulada

frecienciaC['Freciencia A R'] = frecienciaC['Freciencia R'].cumsum()

frecienciaC
# Out:
#   Nivel Escolar  Freciencia AD  Freciencia A AD  Freciencia R  Freciencia A R
# 0   Profesional             11               11          0.22            0.22
# 1   Tecnologico             11               22          0.22            0.44
# 2     Bachiller              8               30          0.16            0.60
# 3       Tecnico              8               38          0.16            0.76
# 4     Postgrado              5               43          0.10            0.86
# 5       Ninguno              5               48          0.10            0.96
# 6      Primaria              2               50          0.04            1.00

# %% [markdown]
# # **Medidas Coso 1**

# %%
#Media o Promedio

media = datasetc['Talla_Zapatos'].mean()

#Mediana

mediana = datasetc['Talla_Zapatos'].median()

#Moda
values, contador = np.unique(datasetc, return_counts=True)
moda = values[np.argmax(contador)]

print(media, mediana, moda)
# Out:
# 38.04 38.0 38

# %%
plt.figure(figsize=(10, 5))
plt.bar(frecienciaC['Nivel Escolar'], frecienciaC['Freciencia AD'], color='#E75018', alpha=0.7)  # Color pastel
# plt.xlabel('Nivel Escolar')
# plt.ylabel('Frecuencia Absoluta')
plt.title('Frecuencia Absoluta por Nivel Escolar')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(frecienciaC['Nivel Escolar'], frecienciaC['Freciencia A AD'], marker='o', linestyle='-', color='red')
# plt.xlabel('Nivel Escolar')
# plt.ylabel('Frecuencia Acumulada')
plt.title('Frecuencia Acumulada por Nivel Escolar')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # **Medidas Coso 2**

# %%
#Media o Promedio

media = datasetUwU['Peso_Estudiantes'].mean()

#Mediana

mediana = datasetUwU['Peso_Estudiantes'].median()

#Moda
# values, contador = np.unique(datasetUwU, return_counts=True)
# moda = values[np.argmax(contador)]
moda = datasetUwU['Peso_Estudiantes'].mode()[0]

value_cont = datasetUwU['Nivel_Escolar'].value_counts()
moda = value_cont[value_cont==value_cont.max()]

print(media, mediana, moda)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\UwU\Documents\python_darkking\MachineLearning\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nivel_Escolar'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 14
#       9 #Moda
# ...

# %%
#aqui grafica 1

# %%
#aqui grafica 2
