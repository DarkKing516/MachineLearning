# %%
import pandas as pd

# %%
data = pd.read_csv('clientes.csv', sep=',', encoding='ISO-8859-1')

data.size
data.shape
data.index
data.columns
data.dtypes

data.values
data.ndim
# Out:
# 2

# %%
data.describe()
# Out:
#        ï»¿ID del cliente  Frecuencia de compra  Valor promedio de la compra  \
# count         157.000000            157.000000                    152.00000
# mean           82.579618              2.369427                    118.23750
# std            47.555248              1.172804                    249.86509
# min             1.000000              1.000000                     20.00000
# 25%            42.000000              1.000000                     65.20000
# 50%            83.000000              2.000000                     85.10000
# 75%           124.000000              3.000000                    120.28750
# max           161.000000              5.000000                   3110.00000
#
#              Edad
# count  154.000000
# mean    31.233766
# std      9.146443
# min      1.000000
# 25%     26.000000
# 50%     30.000000
# 75%     37.000000
# max     80.000000

# %%
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 142 entries, 0 to 156
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ï»¿ID del cliente                  142 non-null    int64
#  1   Nombre                             142 non-null    object
#  2   Ãltima fecha de compra            142 non-null    object
#  3   Frecuencia de compra               142 non-null    int64
#  4   Valor promedio de la compra        142 non-null    float64
#  5   CategorÃ­a de productos comprados  142 non-null    object
#  6   MÃ©todo de pago                    142 non-null    object
#  7   Edad                               142 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 10.0+ KB

# %%
data.head()
# Out:
#    ï»¿ID del cliente           Nombre Ãltima fecha de compra  \
# 0                  1       Juan Perez              15/03/2022
# 1                  2    Ana Rodriguez              01/04/2022
# 2                  3  Luisa Hernandez              10/12/2021
# 3                  4    Carlos Garcia              28/02/2022
# 4                  5      Maria Gomez              20/03/2022
#
#    Frecuencia de compra  Valor promedio de la compra  \
# 0                     5                        200.5
# 1                     2                         80.0
# 2                     3                        150.2
# 3                     1                        300.0
# 4                     4                         75.8
#
#   CategorÃ­a de productos comprados         MÃ©todo de pago  Edad
# 0                              Ropa     Tarjeta de crÃ©dito  32.0
# 1                          Juguetes                Efectivo  45.0
# 2                      ElectrÃ³nica  Transferencia bancaria  28.0
# ...

# %%
data.tail()
# Out:
#      ï»¿ID del cliente           Nombre Ãltima fecha de compra  \
# 152                160      Andrea Soto              09/06/2022
# 153                161  Laura Hernandez              06/06/2022
# 154                145      Luis Garcia              04/06/2022
# 155                154      Luisa Perez              08/06/2022
# 156                160      Andrea Soto              09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 152                     2                         50.0
# 153                     1                        120.0
# 154                     4                         75.2
# 155                     2                         80.0
# 156                     2                         50.0
#
#     CategorÃ­a de productos comprados         MÃ©todo de pago  Edad
# 152                      ElectrÃ³nica  Transferencia bancaria  25.0
# 153                         Alimentos                Efectivo  39.0
# ...

# %%
# data.to_excel('clientes.xlsx')

# %%
resultado = data.iloc[34:40]

resultado
# Out:
#     ï»¿ID del cliente           Nombre Ãltima fecha de compra  \
# 37                 40  Sofia Rodriguez              17/04/2022
# 38                 41   Alberto Torres              28/01/2022
# 39                 42   Julia Martinez              22/04/2022
# 40                 43    Daniel Castro              12/03/2022
# 41                 44       Ana Flores              20/04/2022
# 42                 45  Luisa Hernandez              15/01/2022
#
#     Frecuencia de compra  Valor promedio de la compra  \
# 37                     3                         98.6
# 38                     2                         50.8
# 39                     4                         90.7
# 40                     3                       3110.0
# 41                     1                        200.0
# 42                     2                         80.6
#
#    CategorÃ­a de productos comprados         MÃ©todo de pago  Edad
# 37                      ElectrÃ³nica                Efectivo  32.0
# ...

# %%
# grupo = data.groupby('CategorÃ­a de productos comprados').count
grupo = data.groupby('CategorÃ­a de productos comprados').size()
grupo = data.groupby('CategorÃ­a de productos comprados').agg({'CategorÃ­a de productos comprados':'max'})
grupo
# Out:
#                                   CategorÃ­a de productos comprados
# CategorÃ­a de productos comprados
# Alimentos                                                 Alimentos
# ElectrÃ³nica                                           ElectrÃ³nica
# Juguetes                                                   Juguetes
# Ropa                                                           Ropa

# %%
grupo = data.groupby('CategorÃ­a de productos comprados').min()
grupo = data.groupby('CategorÃ­a de productos comprados').max()
grupo
# Out:
#                                    ï»¿ID del cliente           Nombre  \
# CategorÃ­a de productos comprados
# Alimentos                                        161  Sofia Dominguez
# ElectrÃ³nica                                     160  Sofia Rodriguez
# Juguetes                                         159    Roberto Ortiz
# Ropa                                             158     Sofia Torres
#
#                                   Ãltima fecha de compra  \
# CategorÃ­a de productos comprados
# Alimentos                                      31/03/2022
# ElectrÃ³nica                                   31/03/2022
# Juguetes                                       31/03/2022
# Ropa                                           29/04/2022
#
#                                    Frecuencia de compra  \
# CategorÃ­a de productos comprados
# Alimentos                                             4
# ElectrÃ³nica                                          5
# ...

# %%
resultado = data.groupby('Frecuencia de compra').min()
resultado
# Out:
#                       ï»¿ID del cliente            Nombre  \
# Frecuencia de compra
# 1                                     4     Alberto Ortiz
# 2                                     2    Alberto Torres
# 3                                     3  Alejandro Torres
# 4                                     5     Ana Hernandez
# 5                                     1        Ana Flores
#
#                      Ãltima fecha de compra  Valor promedio de la compra  \
# Frecuencia de compra
# 1                                 01/06/2022                         20.0
# 2                                 01/03/2022                         30.9
# 3                                 01/05/2022                         45.7
# 4                                 04/06/2022                         35.2
# 5                                 15/03/2022                         55.6
#
#                      CategorÃ­a de productos comprados MÃ©todo de pago  Edad
# Frecuencia de compra
# ...

# %%
url = 'https://docs.google.com/spreadsheets/d/1tu-X5KoOkH8DjPUHTgKsqnQR9NeoyVEj/edit#gid=852659367'
path = 'https://docs.google.com/spreadsheets/d/1tu-X5KoOkH8DjPUHTgKsqnQR9NeoyVEj/edit#gid=852659367'

# %%
# URL del archivo de Google Sheets
url = 'https://docs.google.com/spreadsheets/d/1tu-X5KoOkH8DjPUHTgKsqnQR9NeoyVEj/edit#gid=852659367'

# Obtener el ID del archivo de la URL
spreadsheet_id = url.split('/')[-2]

# Construir la URL del archivo de Excel en Google Drive
excel_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=xlsx'

# Leer el archivo de Excel directamente desde Google Drive
data = pd.read_excel(excel_url)

# Ahora puedes usar 'data' como un DataFrame de pandas
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[53], line 11
#       8 excel_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=xlsx'
#      10 # Leer el archivo de Excel directamente desde Google Drive
# ---> 11 data = pd.read_excel(excel_url)
#      13 # Ahora puedes usar 'data' como un DataFrame de pandas
#
# File c:\Users\Sena\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
# ...
